# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv('DATAPROCESS.csv')    # relode the data

# %%
df1.head(10) # top 10 data
# Out:
#    Unnamed: 0       City3  zip_code3  bad3  bath3  Area3 parking3  AC3  \
# 0           0  Austin  TX      78723     2      1    750        2  Yes
# 1           1  Austin  TX      78704     1      1    575        1  Yes
# 2           2  Austin  TX      78704     1      1    654        2  Yes
# 3           3  Austin  TX      78705     1      1    425        1  Yes
# 4           4  Austin  TX      78705     2      2    868        2  Yes
# 5           5  Austin  TX      78751     1      1    640        1  Yes
# 6           6  Austin  TX      78748     2      3   1363        2  Yes
# 7           7  Austin  TX      78745     2      2    914        2  Yes
# 8           8  Austin  TX      78705     1      1    369        1  Yes
# 9           9  Austin  TX      78758     2      2   1784        2  Yes
#
#    price2 Dishwasher1 Refrigerator1 Disposal1 Microwave1 country
# 0   99328         yes            no        no         no     USA
# ...

# %%
df.tail()  # BOTTOM 10 DATA
# Out:
#       Unnamed: 0                        adress3       City3  zip_code3 bad3  \
# 6136        6136          4132 COLE AVE APT 104  Dallas, TX    75204.0    2
# 6137        6137  10572 HIGH HOLLOWS DR APT 160  Dallas, TX    75230.0    2
# 6138        6138          4611 TRAVIS ST # 801B  Dallas, TX    75205.0    2
# 6139        6139     3910 BUENA VISTA ST UNIT 9  Dallas, TX    75204.0    2
# 6140        6140                 3626 SIDNEY ST  Dallas, TX    75210.0    4
#
#      bath3  Area3 parking3  AC3    price2 Dishwasher1 Refrigerator1 Disposal1  \
# 6136     2  1,040  No Info  Yes  157928.0         yes            no        no
# 6137     2    964  No Info  Yes  137148.0         yes            no        no
# 6138     3  1,552  No Info  Yes  349104.0          no            no        no
# 6139     3  1,912        2  Yes  286764.0         yes            no        no
# 6140     3  1,899  No Info  Yes  211540.0          no            no        no
#
#      Microwave1 country
# ...

# %% [markdown]
# ### as absarving the above data set we can see the column name Appliances3 has clustar of data wich we dont whatnt .
# ### also we have data like 	Unnamed: 0	 and adress3 wich unique identification .

# %%
df1.columns.to_list() # ALL COLUMNS NAME IN LIST
# Out:
# ['Unnamed: 0',
#  'City3',
#  'zip_code3',
#  'bad3',
#  'bath3',
#  'Area3',
#  'parking3',
#  'AC3',
#  'price2',
#  'Dishwasher1',
#  'Refrigerator1',
#  'Disposal1',
#  'Microwave1',
#  'country']

# %%
print('columns in data=',df.shape[1])
# Out:
# columns in data= 15

# %%
df.info()     # BASIC INFORMATION ABOUT DATA SET
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6141 entries, 0 to 6140
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     6141 non-null   int64
#  1   adress3        5314 non-null   object
#  2   City3          5865 non-null   object
#  3   zip_code3      5315 non-null   float64
#  4   bad3           6022 non-null   object
#  5   bath3          6022 non-null   object
#  6   Area3          6022 non-null   object
#  7   parking3       6022 non-null   object
#  8   AC3            6022 non-null   object
#  9   price2         6141 non-null   float64
#  10  Dishwasher1    6141 non-null   object
#  11  Refrigerator1  6141 non-null   object
#  12  Disposal1      6141 non-null   object
#  13  Microwave1     6141 non-null   object
#  14  country        6141 non-null   object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 719.8+ KB

# %% [markdown]
# ### as we can see there are columns wech should have int typoe data but they are object type
# ### we have to fix them

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# adress3          827
# City3            276
# zip_code3        826
# bad3             119
# bath3            119
# Area3            119
# parking3         119
# AC3              119
# price2             0
# Dishwasher1        0
# Refrigerator1      0
# Disposal1          0
# Microwave1         0
# country            0
# dtype: int64

# %% [markdown]
# ### as seen in nabove methode the coluimns contain null values .

# %%
sns.heatmap(df.isna(),color='red')
# Out:
# <Axes: >

# %% [markdown]
# ### we are going to drop all rows who has null value
# ### becouse of we are going to import these data in SQL DATABASE .

# %%
df1=df.dropna()

# %%
sns.heatmap(df1.isna(),color='red')
# Out:
# <Axes: >

# %%
print('rows in data=',df1.shape[0])
print('columns in data=',df1.shape[1])
# Out:
# rows in data= 5314
# columns in data= 15

# %%
df1
# Out:
#       Unnamed: 0                        adress3       City3  zip_code3 bad3  \
# 0              0          6110 WHELESS CV APT C  Austin, TX    78723.0    2
# 1              1              2208 DEL CURTO RD  Austin, TX    78704.0    1
# 2              2                412 W ALPINE RD  Austin, TX    78704.0    1
# 3              3          502 W 35TH ST APT 105  Austin, TX    78705.0    1
# 4              4           2502 LEON ST APT 415  Austin, TX    78705.0    2
# ...          ...                            ...         ...        ...  ...
# 6136        6136          4132 COLE AVE APT 104  Dallas, TX    75204.0    2
# 6137        6137  10572 HIGH HOLLOWS DR APT 160  Dallas, TX    75230.0    2
# 6138        6138          4611 TRAVIS ST # 801B  Dallas, TX    75205.0    2
# 6139        6139     3910 BUENA VISTA ST UNIT 9  Dallas, TX    75204.0    2
# 6140        6140                 3626 SIDNEY ST  Dallas, TX    75210.0    4
#
# ...

# %% [markdown]
# ### we still need to clen data little bit

# %%
df1['City3']=df1['City3'].str.replace(',',' ')  # replacing ',' from city3

# %%
df1['Area3']=df1['Area3'].str.replace(',','')  # replacing ',' from Area3

# %%
df1['zip_code3'] = df1['zip_code3'].astype(int)    # removing '.0' from zipcode

# %%
df1['price2'] = df1['price2'].astype(int)    # removing '.0' from price

# %%
df1['bad3'] = df1['bad3'].astype(int)    # removing '.0' from zipcode
df['bad3'] = df['bad3'].astype(int)    # removing '.0' from zipcode
df['Area3'] = df['Area3'].astype(int)    # removing '.0' from zipcode

# %%
df1['Area3'].value_counts()

# %%
df1['Area3']=df1['Area3'].str.replace('MLS#','0')  # replacing ',' from Area3

# %%
df['bath3']=df['bath3'].str.replace('R1','1')  # replacing ',' from Area3

# %%
df['bad3']=df['bad3'].str.replace('0.88','1')  # replacing ',' from Area3

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5314 entries, 0 to 6140
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     5314 non-null   int64
#  1   adress3        5314 non-null   object
#  2   City3          5314 non-null   object
#  3   zip_code3      5314 non-null   int32
#  4   bad3           5314 non-null   int32
#  5   bath3          5314 non-null   int32
#  6   Area3          5314 non-null   int32
#  7   parking3       5314 non-null   object
#  8   AC3            5314 non-null   object
#  9   price2         5314 non-null   int32
#  10  Dishwasher1    5314 non-null   object
#  11  Refrigerator1  5314 non-null   object
#  12  Disposal1      5314 non-null   object
#  13  Microwave1     5314 non-null   object
#  14  country        5314 non-null   object
# dtypes: int32(5), int64(1), object(9)
# memory usage: 560.5+ KB

# %%
df1.nunique()
# Out:
# Unnamed: 0       5314
# adress3          5130
# City3              41
# zip_code3         449
# bad3                7
# bath3               7
# Area3            1823
# parking3           26
# AC3                 3
# price2            732
# Dishwasher1         2
# Refrigerator1       1
# Disposal1           2
# Microwave1          2
# country             1
# dtype: int64

# %%
df1.drop('adress3',axis=1,inplace=True)

# %%
df1.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df1.nunique().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### by abserving this plot the Area3column has
# ### the highest number of unique value after that price{Labal} has the second highest.

# %%
for i in df1.columns:
    print(df1[i].value_counts())
    print('/n'*75)
# Out:
# Dallas  TX             668
# Phoenix  AZ            595
# WASHINGTON  DC         569
# ORLANDO  FL            520
# Las Vegas  NV          514
# Chicago  IL            512
# Austin  TX             472
# Houston  TX            452
# San Diego  CA          352
# San Francisco  CA      161
# Buffalo  NY            117
# Newark  NJ              92
# La Jolla  CA            55
# Portland  TX            42
# NEWARK  DE              38
# Jersey City  NJ         35
# Scottsdale  AZ          30
# SAN FRANCISCO  CA       17
# University Park  TX     14
# Farmers Branch  TX       6
# Miami  FL                6
# Orlando  FL              5
# Ottawa  KS               5
# san diego  CA            5
# Highland Park  TX        4
# SAN DIEGO  CA            4
# Cave Creek  AZ           3
# Del Mar  CA              3
# Ottawa  IL               3
# Newark  OH               2
# NEWARK  CA               2
# Lakeway  TX              2
# LA JOLLA  CA             1
# La jolla  CA             1
# ...

# %%
df1.corr()
# Out:
#            zip_code3      bad3     bath3     Area3    price2
# zip_code3   1.000000 -0.115721  0.039217  0.015834  0.017437
# bad3       -0.115721  1.000000  0.678285  0.022701  0.004856
# bath3       0.039217  0.678285  1.000000  0.028883  0.002039
# Area3       0.015834  0.022701  0.028883  1.000000  0.000842
# price2      0.017437  0.004856  0.002039  0.000842  1.000000

# %% [markdown]
# ### the above are the count of all unique value.

# %%
df1.describe()
# Out:
#           zip_code3         bad3        bath3          Area3        price2
# count   5314.000000  5314.000000  5314.000000    5314.000000  5.314000e+03
# mean   65247.639255     2.101807     1.860557    1593.327437  5.030467e+05
# std    26630.416623     0.963665     0.890766   12878.389539  8.352583e+06
# min     7103.000000     1.000000     1.000000       0.000000  0.000000e+00
# 25%    32837.000000     1.000000     1.000000     756.000000  1.329920e+05
# 50%    77002.500000     2.000000     2.000000    1086.000000  1.828640e+05
# 75%    85023.000000     3.000000     2.000000    1564.750000  2.576720e+05
# max    94560.000000     7.000000     7.000000  842662.000000  4.322240e+08

# %% [markdown]
# ### the decribe method give us the detail of numerical columns
# ### by observing the describe method we can see.
# ### 1) count for all columns is same as no of rows present¶
# ### 2) column zip_code3 and bathe3 has high median value that mean value it has some left skeew
# ### 3) column Area and price has high mean value then median that means it has some right side skewness
# ### 3 column bad3 mean and median(50%) has equal.
# ### 4) columns bad3,bath3 and Area3 has high max value as comapair to there 75% value .that means it can be a outlairs.

# %%
df1.skew()
# Out:
# zip_code3    -0.875430
# bad3          0.921650
# bath3         1.022693
# Area3        56.152236
# price2       46.270805
# dtype: float64

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='City3',data=df1)
# Out:
# <Axes: xlabel='City3', ylabel='count'>

# %% [markdown]
# ### as seen in above plot the column has very much of unique value

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='zip_code3',data=df1)
# Out:
# <Axes: xlabel='zip_code3', ylabel='count'>

# %% [markdown]
# ### this column also have very high unique value

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='parking3',data=df1)
# Out:
# <Axes: xlabel='parking3', ylabel='count'>

# %% [markdown]
# ### as seen above plot parking column has very big amount of no info value.

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='AC3',data=df1)
# Out:
# <Axes: xlabel='AC3', ylabel='count'>

# %% [markdown]
# ### as seen in the plot AC column has very high percentege of yes .

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Dishwasher1',data=df1)
# Out:
# <Axes: xlabel='Dishwasher1', ylabel='count'>

# %% [markdown]
# ### the dishwashar column has very high count of no

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Refrigerator1',data=df1)
# Out:
# <Axes: xlabel='Refrigerator1', ylabel='count'>

# %% [markdown]
# ### the above plot show the refigerator column has only no in it .

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Disposal1',data=df1)
# Out:
# <Axes: xlabel='Disposal1', ylabel='count'>

# %% [markdown]
# ### the disposal column has very high count of no

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Microwave1',data=df1)
# Out:
# <Axes: xlabel='Microwave1', ylabel='count'>

# %% [markdown]
# ### the microwave column also has very high bcount of no

# %%
df1['bad3'].plot(figsize=(12,7), legend=True)
df1['bath3'].plot(figsize=(12,7), color='r', legend=True)
plt.title('bad and bath')
# Out:
# Text(0.5, 1.0, 'bad and bath')

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='country',data=df1)
# Out:
# <Axes: xlabel='country', ylabel='count'>

# %% [markdown]
# ## as seen in above we have only one country and that is USA

# %% [markdown]
# # bivariate¶

# %%
sns.scatterplot( x='bad3',y='bath3',data=df1,hue='City3',palette='bright')
plt.title("relation between bad and bath ")
# Out:
# Text(0.5, 1.0, 'relation between bad and bath ')

# %%
sns.scatterplot( x='bad3',y='Area3',data=df1,hue='City3',palette='bright')
plt.title("relation between bad and Area ")
# Out:
# Text(0.5, 1.0, 'relation between bad and Area ')

# %%
sns.scatterplot( x='Area3',y='bath3',data=df1,hue='City3',palette='bright')
plt.title("relation between Area and bath ")
# Out:
# Text(0.5, 1.0, 'relation between Area and bath ')

# %%
sns.scatterplot( x='Area3',y='price2',data=df1,hue='City3',palette='bright')
plt.title("relation between Area and price ")
# Out:
# Text(0.5, 1.0, 'relation between Area and price ')

# %%
sns.scatterplot( x='AC3',y='price2',data=df1,hue='City3',palette='bright')
plt.title("relation between AC3 and price2 ")
# Out:
# Text(0.5, 1.0, 'relation between AC3 and price2 ')

# %%
sns.scatterplot( x='parking3',y='price2',data=df1,hue='City3',palette='bright')
plt.title("relation between parking3 and price2 ")
# Out:
# Text(0.5, 1.0, 'relation between parking3 and price2 ')

# %%
sns.pairplot(df1)

# %% [markdown]
# ### we can see the relation betwen columns  on above plot

# %%
df1.skew()
# Out:
# zip_code3    -0.875430
# bad3          0.921650
# bath3         1.022693
# Area3        56.152236
# price2       46.270805
# dtype: float64

# %%
dfi=df1[{'zip_code3','bad3','bath3','Area3','price2'}]  # making sapret dataframe for int or flot type data

# %% [markdown]
# ### lets chek the outliers.¶

# %%
plt.figure(figsize=(20,15))
value=1
for col in dfi:
    if value <=5:
        g=plt.subplot(3,2,value)
        sns.boxplot(dfi[col],palette="Set2_r")
        plt.xlabel(col,fontsize=14)
        plt.yticks(rotation=0,fontsize=14)
    value+=1
plt.tight_layout()

# %% [markdown]
# ### as observing the box plot the labal has so much outliers
# ### lets chek with the z score method¶

# %%
from scipy import stats
from scipy.stats import zscore

# %%
z=np.abs(zscore(dfi))

# %%
z
# Out:
#          Area3     bath3    price2  zip_code3      bad3
# 0     0.349258  1.001960  0.156137   0.504618  0.081781
# 1     0.467067  1.001960  0.125040   0.503904  1.164547
# 2     0.413885  1.001960  0.128538   0.503904  1.164547
# 3     0.568047  1.001960  0.171685   0.503941  1.164547
# 4     0.269821  0.211268  0.132814   0.503941  0.081781
# ...        ...       ...       ...        ...       ...
# 5238  0.154031  0.211268  0.101328   0.372381  0.081781
# 5239  0.205194  0.211268  0.120764   0.373358  0.081781
# 5240  0.190645  1.424495  0.077480   0.372419  0.081781
# 5241  0.432996  1.424495  0.019173   0.372381  0.081781
# 5242  0.424244  1.424495  0.051184   0.372607  2.083752
#
# [5243 rows x 5 columns]

# %%
np.where(z>3)
# Out:
# (array([ 258,  501,  511,  522,  550,  551,  553,  581,  734,  743, 1115,
#         1173, 1180, 1261, 1269, 1275, 1292, 1296, 1299, 1316, 1324, 1325,
#         1348, 1372, 1393, 1463, 1471, 1534, 1597, 1605, 1630, 1631, 1635,
#         1637, 1650, 1653, 1662, 1668, 1680, 1723, 1745, 1763, 1772, 1784,
#         1807, 1810, 1824, 1831, 1847, 1856, 1906, 1923, 1946, 1990, 2060,
#         2169, 2172, 2201, 2233, 2244, 2246, 2247, 2248, 2248, 2416, 2776,
#         2810, 2875, 3117, 3180, 3269, 3334, 3335, 3376, 3386, 3485, 3488,
#         3615, 3623, 3649, 3677, 3715, 3807, 3840, 3842, 3865, 3886, 3958,
#         4001, 4092, 4198, 4288, 4410, 4442, 4470, 4478, 4564, 4618, 4809,
#         4836, 4939, 4942, 4977, 5009, 5025, 5054], dtype=int64),
#  array([2, 0, 4, 0, 0, 0, 0, 0, 2, 0, 4, 2, 0, 4, 4, 4, 4, 4, 4, 0, 4, 4,
#         4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 2, 4, 4, 4, 4,
#         4, 4, 4, 4, 2, 4, 4, 4, 4, 2, 4, 4, 4, 4, 4, 2, 2, 2, 2, 4, 2, 0,
# ...

# %%
df1.iloc[348]
# Out:
# Unnamed: 0              369
# City3            Austin  TX
# zip_code3             78705
# bad3                      2
# bath3                     2
# Area3                   621
# parking3                  2
# AC3                     Yes
# price2               128836
# Dishwasher1             yes
# Refrigerator1            no
# Disposal1                no
# Microwave1               no
# country                 USA
# Name: 348, dtype: object

# %%
df1=df1[(z<3).all(axis=1)]

# %%
df1.shape
# Out:
# (5138, 14)

# %%
print('old data shape',df.shape)
print('new data shape',df1.shape)
# Out:
# old data shape (6141, 15)
# new data shape (5243, 13)

# %%
print('data loss percentege',((df.shape[0]-df1.shape[0])/df.shape[0]*100))
# Out:
# data loss percentege 13.466862074580687

# %% [markdown]
# ### now cheking the distribution of data

# %%
dfi=df1[{'zip_code3','bad3','bath3','Area3','price2'}]  # making sapret dataframe for int or flot type data

# %%
plt.figure(figsize=(15,10))
plot_v=1
for col in dfi:
    if plot_v <=5:
        p=plt.subplot(3,2,plot_v)
        sns.distplot(dfi[col],color='red')
        plt.xlabel(col,fontsize=10)
        plt.yticks(rotation=0,fontsize=10)
    plot_v+=1
plt.tight_layout() 
dfi.skew()
# Out:
# Area3        19.639820
# bath3         0.643076
# price2       20.361722
# zip_code3    -0.879784
# bad3          0.787205
# dtype: float64

# %%
df1['price2']=np.cbrt(df1['price2'])
df1['Area3']=np.cbrt(df1['Area3'])

# %%
df1.skew()
# Out:
# Unnamed: 0   -0.185469
# zip_code3    -0.879784
# bad3          0.787205
# bath3         0.643076
# Area3        -0.992194
# price2        4.045860
# dtype: float64

# %% [markdown]
# ### now its looking better.¶

# %% [markdown]
# ### let chek if data has any multicolinearty issue.¶

# %%
df1.corr()
# Out:
#            zip_code3      bad3     bath3     Area3    price2
# zip_code3   1.000000 -0.109752  0.050024  0.164161  0.016634
# bad3       -0.109752  1.000000  0.662698  0.389457  0.146427
# bath3       0.050024  0.662698  1.000000  0.447063  0.213334
# Area3       0.164161  0.389457  0.447063  1.000000  0.135974
# price2      0.016634  0.146427  0.213334  0.135974  1.000000

# %%
cor=df1.corr()
plt.figure(figsize=(15,15))
sns.heatmap(cor,linewidths=0.1,fmt='.1g',linecolor='black',annot= True,cmap='Blues_r') # ploting heatmap of corr method.
# Out:
# <Axes: >

# %% [markdown]
# ### the corr method give us the correlation of numerical columns
# ### the column zip_code and bad are negativly correlated with each othar
# ### columns price is also positive  correlated with othar  columns
# ### as absarve the columns are not highly correlated with each othar

# %% [markdown]
# ### now lets encode the object type columns.

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()                                  # encoding withe the lebal encoder.
df1['City3'] = label_encoder.fit_transform(df1['City3'])
df1['parking3'] = label_encoder.fit_transform(df1['parking3'])
df1['AC3'] = label_encoder.fit_transform(df1['AC3'])
df1['Dishwasher1'] = label_encoder.fit_transform(df1['Dishwasher1'])
df1['Refrigerator1'] = label_encoder.fit_transform(df1['Refrigerator1'])
df1['Disposal1'] = label_encoder.fit_transform(df1['Disposal1'])
df1['Microwave1'] = label_encoder.fit_transform(df1['Microwave1'])
df1['country'] = label_encoder.fit_transform(df1['country'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5243 entries, 0 to 5242
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   City3          5243 non-null   object
#  1   zip_code3      5243 non-null   int64
#  2   bad3           5243 non-null   int64
#  3   bath3          5243 non-null   int64
#  4   Area3          5243 non-null   float64
#  5   parking3       5243 non-null   object
#  6   AC3            5243 non-null   object
#  7   price2         5243 non-null   float64
#  8   Dishwasher1    5243 non-null   object
#  9   Refrigerator1  5243 non-null   object
#  10  Disposal1      5243 non-null   object
#  11  Microwave1     5243 non-null   object
#  12  country        5243 non-null   object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 532.6+ KB

# %%
DFXR1=df1.drop('price2', axis=1)
DFYR1=df1['price2']
DFXR2=df1.drop('Area3', axis=1)
DFYR2=df1['Area3']

# %%
DFXR1.drop(['Refrigerator1','Disposal1','Microwave1','country','Dishwasher1'],axis=1,inplace=True)

# %%
DFXR2.drop(['Refrigerator1','Disposal1','Microwave1','country','Dishwasher1'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
scal=StandardScaler()

# %%
DFXR1=pd.DataFrame(scal.fit_transform(DFXR1),columns=DFXR1.columns)

# %%
DFXR2=pd.DataFrame(scal.fit_transform(DFXR2),columns=DFXR2.columns)

# %%
DFXR1.describe()
# Out:
#              City3          bad3         bath3        Area3      parking3  \
# count  5243.000000  5.243000e+03  5.243000e+03  5243.000000  5.243000e+03
# mean      0.000000 -1.626266e-17  1.084177e-17     0.000000  2.168355e-17
# std       1.000095  1.000095e+00  1.000095e+00     1.000095  1.000095e+00
# min      -1.510172 -1.164547e+00 -1.001960e+00    -3.318438 -1.388497e+00
# 25%      -0.943826 -1.164547e+00 -1.001960e+00    -0.319522 -5.236510e-01
# 50%      -0.134762 -8.178054e-02  2.112677e-01     0.059833 -5.236510e-01
# 75%       0.836116  1.000986e+00  2.112677e-01     0.493163  1.013853e+00
# max       1.726087  3.166518e+00  2.637722e+00     8.420186  1.013853e+00
#
#                 AC3
# count  5.243000e+03
# mean  -2.710443e-17
# std    1.000095e+00
# min   -4.378409e+00
# 25%    3.353483e-01
# 50%    3.353483e-01
# 75%    3.353483e-01
# max    3.353483e-01

# %%
DFXR2.describe()
# Out:
#              City3          bad3         bath3      parking3           AC3  \
# count  5243.000000  5.243000e+03  5.243000e+03  5.243000e+03  5.243000e+03
# mean      0.000000 -1.626266e-17  1.084177e-17  2.168355e-17 -2.710443e-17
# std       1.000095  1.000095e+00  1.000095e+00  1.000095e+00  1.000095e+00
# min      -1.510172 -1.164547e+00 -1.001960e+00 -1.388497e+00 -4.378409e+00
# 25%      -0.943826 -1.164547e+00 -1.001960e+00 -5.236510e-01  3.353483e-01
# 50%      -0.134762 -8.178054e-02  2.112677e-01 -5.236510e-01  3.353483e-01
# 75%       0.836116  1.000986e+00  2.112677e-01  1.013853e+00  3.353483e-01
# max       1.726087  3.166518e+00  2.637722e+00  1.013853e+00  3.353483e-01
#
#              price2
# count  5.243000e+03
# mean   2.710443e-18
# std    1.000095e+00
# min   -3.221430e+00
# 25%   -3.552745e-01
# 50%   -3.429366e-02
# 75%    3.128436e-01
# max    1.371105e+01

# %% [markdown]
# # regrresion¶1

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression  
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import ExtraTreesRegressor

# %% [markdown]
# ### now lets find the good random state value as par the data.

# %%
MAXXACU=0
MAXRS=0
for i in range(1,250):
    x_train,x_test,y_train,y_test=train_test_split(DFXR1,DFYR1,test_size=0.30,random_state=i)
    ler=LinearRegression()
    ler.fit(x_train,y_train)
    pred=ler.predict(x_test)
    acc=r2_score(y_test,pred)   # finding best rendom state for data set.
    if acc>MAXXACU:
        MAXXACU=acc
        MAXRS=i
print('MAX R2_score is-',MAXXACU,'BEST rendom state is',MAXRS)
# Out:
# MAX R2_score is- 0.1465018211493585 BEST rendom state is 150

# %%
x_train,x_test,y_train,y_test=train_test_split(DFXR1,DFYR1,test_size=0.30,random_state=MAXRS)

# %% [markdown]
# ### making all modal as a singal modal

# %%
models = {
    'LinearRegression' : LinearRegression(),
    'DecisionTree'     : DecisionTreeRegressor(),
    'RandomForest'     : RandomForestRegressor(),
    'Ridge'            : Ridge(),
    'Lasso'            : Lasso(),
    'SVR'              : SVR(),
    'ElasticNet'       : ElasticNet(),
    'KNeighborsRegressor':KNeighborsRegressor(),
    'GradientBoostingRegressor':GradientBoostingRegressor(),
    'XGBRegressor'      :  XGBRegressor(),
    'ExtraTreesRegressor':ExtraTreesRegressor()
}

# %% [markdown]
# ### defing the all evaluation method to one

# %%
def evaluation(model, prediction, x_train, y_train, x_test, y_test):
    print('mean absolute error : %.2f' % mean_absolute_error(y_test,prediction)) 
    print('mean_squared error: %.2f' % mean_squared_error(y_test, prediction, squared=False)) 
    print('R2 score : %.2f' % r2_score(y_test, prediction)) 
    print('Train Accuracy :', model.score(x_train, y_train)) 
    print('Test Accuracy :', model.score(x_test, y_test))

# %% [markdown]
# ### Nnow lets train all modal at once,

# %%
for model_name, model in models.items():
    model.fit(x_train, y_train)
    prediction1 = model.predict(x_test)
    print('Model: {}'.format(model_name))
    print(evaluation(model, prediction1, x_train, y_train, x_test, y_test), 
          '\n')
# Out:
# Model: LinearRegression
# mean absolute error : 7.39
# mean_squared error: 13.42
# R2 score : 0.15
# Train Accuracy : 0.07068694438505174
# Test Accuracy : 0.1465018211493585
# None
#
# Model: DecisionTree
# mean absolute error : 9.35
# mean_squared error: 23.36
# R2 score : -1.59
# Train Accuracy : 0.9235891320044596
# Test Accuracy : -1.5852747429028402
# None
#
# Model: RandomForest
# mean absolute error : 7.31
# mean_squared error: 14.34
# R2 score : 0.03
# Train Accuracy : 0.8057375863653573
# Test Accuracy : 0.025637986903754295
# None
#
# Model: Ridge
# mean absolute error : 7.39
# mean_squared error: 13.42
# R2 score : 0.15
# Train Accuracy : 0.07068693961699246
# Test Accuracy : 0.14649094692026143
# None
#
# Model: Lasso
# mean absolute error : 7.63
# mean_squared error: 13.63
# R2 score : 0.12
# Train Accuracy : 0.060613820548758635
# Test Accuracy : 0.1199958652738109
# None
#
# Model: SVR
# mean absolute error : 6.38
# mean_squared error: 12.94
# R2 score : 0.21
# ...

# %% [markdown]
# ### i traid multiple combination of columns the data is not giving respectfull out put.

# %%
DFXR2.drop('zip_code3',axis=1,inplace=True)
